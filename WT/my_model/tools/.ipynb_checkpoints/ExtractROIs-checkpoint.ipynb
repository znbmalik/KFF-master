# %%
import matplotlib
import sys
import os
import _init_paths
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
sys.path.insert(0, '/home/tf-faster-rcnn/lib/lk_roi_data_layer')
import Data_LK_Layer
from ROI_pooling import ROIPoolingLayer

from tensorflow.keras import backend as k
config=tf.ConfigProto()
config.gpu_options.allow_growth=True
sess=tf.Session(config=config)
k.set_session(sess)

print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# 1.12.0
# 2.1.6-tf

# %%
interval=8 #1,4,8
channel=10 # 110,25,10
t_folder='_Training_Npy' #_Training_Npy, _Validation_Npy
roi_folder='_ROI_Train_Npy' #_ROI_Train_Npy, #_ROI_Val_Npy
algo='LK_Flow_StackedFrames'
#LK_Flow_StackedFrames, Brox_Flow_StackedFrames,PLK_Flow_StackedFrames,Tvl1_Flow_StackedFrames,Farneback_Flow_StackedFrames

# %%
#ROI Result Folder
roi_path=os.path.join('/home/tf-faster-rcnn/my_data/'+algo+'/'+str(interval)+roi_folder)
if not os.path.exists(roi_path):
    os.makedirs(roi_path)
else:
    for f in os.listdir(roi_path):
        if f is not ".ipynb_checkpoints":
            os.remove(os.path.join(roi_path,f))

# %%
import os
count=0
for file in os.listdir('/home/tf-faster-rcnn/my_data/'+algo+'/'+str(interval)+t_folder):
    
    temp=Data_LK_Layer.Data_LK_Layer('/home/tf-faster-rcnn/my_data/'+algo+'/'+str(interval),channel, file)
    if len(temp._roidb)>0:
        top=temp.outputGenerator()
        print(top[0].shape)
        top[0]=top[0].transpose(0,2,3,1)

        # Define parameters
        batch_size = 1
        img_height = 240
        img_width = 320
        n_channels = channel

        n_rois = len(top[2])
        pooled_height = 25
        pooled_width = 35

        # Create feature map input
        feature_maps_shape = (batch_size, img_height, img_width, n_channels)
        feature_maps_tf = tf.placeholder(tf.float32, shape=feature_maps_shape)       
        feature_maps_np = np.asarray(top[0], dtype='float32')       
        feature_maps_np[0, img_height-1, img_width-3, 0] = 50

        # Create batch size
        roiss_tf = tf.placeholder(tf.float32, shape=(batch_size, n_rois, 4))
        roiss_np = np.asarray([top[2][:,1:5]], dtype='float32')      

        # Create layer
        roi_layer = ROIPoolingLayer(pooled_height, pooled_width)
        pooled_features = roi_layer([feature_maps_tf, roiss_tf])   
        
    
        '''result = sess.run(pooled_features, feed_dict={feature_maps_tf:feature_maps_np,roiss_tf:roiss_np})
        print("-------------result.shape", result.shape)
        for i in range(result.shape[1]): 
            print("-------------saving : Roi_"+str(count)+"_"+str(int(top[1][i]))+".npy---------")
            np.save(roi_path+"/Roi_"+str(count)+"_"+str(int(top[1][i]))+".npy", result[0,i,:,:,:])
            count=count+1
    temp=None
    top=None
    result=None'''
# Out:
# v_BabyCrawling_g08_c01.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g08_c03.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g08_c04.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c01.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c02.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c03.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c05.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c06.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c01.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c02.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c03.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c05.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g11_c01.npy
# (1, 10, 240, 320)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-959c1a42b162> in <module>()
#      31         # Create layer
#      32         roi_layer = ROIPoolingLayer(pooled_height, pooled_width)
# ...

# %%
import os
count=0

# Define parameters
batch_size = 1
img_height = 240
img_width = 320
n_channels = channel
pooled_height = 25
pooled_width = 35






for file in os.listdir('/home/tf-faster-rcnn/my_data/'+algo+'/'+str(interval)+t_folder):
    
    temp=Data_LK_Layer.Data_LK_Layer('/home/tf-faster-rcnn/my_data/'+algo+'/'+str(interval),channel, file)
    if len(temp._roidb)>0:
        top=temp.outputGenerator()
        print(top[0].shape)
        top[0]=top[0].transpose(0,2,3,1)

        n_rois = len(top[2])

        # Create feature map input
        feature_maps_shape = (batch_size, img_height, img_width, n_channels)
        feature_maps_tf = tf.placeholder(tf.float32, shape=feature_maps_shape)       
        feature_maps_np = np.asarray(top[0], dtype='float32')       
        feature_maps_np[0, img_height-1, img_width-3, 0] = 50

        # Create batch size
        roiss_tf = tf.placeholder(tf.float32, shape=(batch_size, n_rois, 4))
        roiss_np = np.asarray([top[2][:,1:5]], dtype='float32')      

        # Create layer
        roi_layer = ROIPoolingLayer(pooled_height, pooled_width)
        pooled_features = roi_layer([feature_maps_tf, roiss_tf])   
        
        '''result = sess.run(pooled_features, feed_dict={feature_maps_tf:feature_maps_np,roiss_tf:roiss_np})
        print("-------------result.shape", result.shape)
        for i in range(result.shape[1]): 
            print("-------------saving : Roi_"+str(count)+"_"+str(int(top[1][i]))+".npy---------")
            np.save(roi_path+"/Roi_"+str(count)+"_"+str(int(top[1][i]))+".npy", result[0,i,:,:,:])'''
            #count=count+1
        del roi_layer 
        del temp
        del feature_maps_shape
        del feature_maps_tf
        del feature_maps_np
        del roiss_tf
        del roiss_np
        del pooled_features
# Out:
# v_BabyCrawling_g08_c01.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g08_c03.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g08_c04.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c01.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c02.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c03.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c05.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g09_c06.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c01.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c02.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c03.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g10_c05.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g11_c01.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g11_c02.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g11_c04.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g12_c02.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g12_c03.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g12_c04.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g12_c05.npy
# (1, 10, 240, 320)
# v_BabyCrawling_g12_c06.npy
# (1, 10, 240, 320)
# ...
