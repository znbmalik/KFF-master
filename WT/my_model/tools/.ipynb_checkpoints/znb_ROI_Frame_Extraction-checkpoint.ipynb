# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import matplotlib
matplotlib.use('Agg')
import _init_paths
from model.config import cfg
from model.test import im_detect
from model.nms_wrapper import nms

from utils.timer import Timer
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os, cv2,sys
import argparse

sys.path.insert(0, '/home/my_model/lib/motion')#-----------Zainab model  
import CaptureFrames as cap#-----------Zainab model
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
out_frames_path= '/home/my_model/my_data/Crop_Frames/' #-----------Zainab model

depth=2
interval=1
input_path = '/home/my_model/my_data/depth_'+str(depth)+'/'+str(interval)

# %%
if not os.path.exists(out_frames_path):
    os.makedirs(out_frames_path)
else:
    files = os.listdir(out_frames_path)
    print(files)
    for f in files:
        print(f)
        os.remove(os.path.join(out_frames_path,f))
        print("removed")

# %%
for folder in os.listdir(input_path):
    
    #Will iterate for all folders containing videos or all categories of videos in data set'''
    
    if folder is not '.ipynb_checkpoints':
        fullPath = os.path.join(input_path, folder)
        if os.path.isdir(fullPath):
            for files in os.listdir(fullPath):
                '''Will iterate for every video in every folder or category in data set'''

                video=os.path.join(fullPath,files)
                

                '''call a class that will capture all frames from a provided videos, exist in a folder Train_videos, and put in a                           folder Training_Frame. to add another category of videos r to add more videos in exxisting category we need to upload                       videos in /home/FRCN/data/Train_videos folder'''
                totalFrames=cap.extract_frames(video,depth,interval) #-----------Zainab model
                print("-------------Extracted "+str(totalFrames[0])+" from "+video+"--------------")
                
    

print("*****************Next Step: Detect Human using my_motion_demo_From_Img************************")
# Out:
# -------------Extracted 17 from /home/my_model/my_data/Crop_Videos/BodyWeightSquats/clip_1_v_BodyWeightSquats_g11_c01.avi--------------
# -------------Extracted 17 from /home/my_model/my_data/Crop_Videos/BodyWeightSquats/clip_0_v_BodyWeightSquats_g17_c01.avi--------------
# -------------Extracted 17 from /home/my_model/my_data/Crop_Videos/BodyWeightSquats/clip_0_v_BodyWeightSquats_g20_c02.avi--------------
# -------------Extracted 17 from /home/my_model/my_data/Crop_Videos/BodyWeightSquats/clip_2_v_BodyWeightSquats_g25_c05.avi--------------
# -------------Extracted 17 from /home/my_model/my_data/Crop_Videos/BodyWeightSquats/clip_0_v_BodyWeightSquats_g09_c04.avi--------------
# -------------Extracted 17 from /home/my_model/my_data/Crop_Videos/BodyWeightSquats/clip_0_v_BodyWeightSquats_g01_c03.avi--------------
# -------------Extracted 17 from /home/my_model/my_data/Crop_Videos/BodyWeightSquats/clip_1_v_BodyWeightSquats_g14_c03.avi--------------
# ...
